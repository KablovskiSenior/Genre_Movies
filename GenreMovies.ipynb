# %% [markdown]
# <a href="https://colab.research.google.com/github/KablovskiSenior/Genre_Movies/blob/main/GenreMovies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import nltk
from nltk import ngrams
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
nltk.download('wordnet')


# make sure you imported the kaggle dataset and have it on the same directory as this.
file = "wiki_movie_plots_deduped.csv"

df = pd.read_csv(file)
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#        Release Year                             Title Origin/Ethnicity  \
# 0              1901            Kansas Saloon Smashers         American
# 1              1901     Love by the Light of the Moon         American
# 2              1901           The Martyred Presidents         American
# 3              1901  Terrible Teddy, the Grizzly King         American
# 4              1902            Jack and the Beanstalk         American
# ...             ...                               ...              ...
# 34881          2014                 The Water Diviner          Turkish
# 34882          2017                Çalgı Çengi İkimiz          Turkish
# 34883          2017                      Olanlar Oldu          Turkish
# 34884          2017                  Non-Transferable          Turkish
# 34885          2017                İstanbul Kırmızısı          Turkish
#
#                                  Director  \
# 0                                 Unknown
# 1                                 Unknown
# 2                                 Unknown
# 3                                 Unknown
# 4      George S. Fleming, Edwin S. Porter
# ...                                   ...
# 34881             Director: Russell Crowe
# 34882                      Selçuk Aydemir
# 34883                         Hakan Algül
# 34884                     Brendan Bradley
# 34885                      Ferzan Özpetek
#
#                                                     Cast            Genre  \
# 0                                                    NaN          unknown
# 1                                                    NaN          unknown
# 2                                                    NaN          unknown
# 3                                                    NaN          unknown
# 4                                                    NaN          unknown
# ...                                                  ...              ...
# 34881  Director: Russell Crowe\r\nCast: Russell Crowe...          unknown
# 34882                          Ahmet Kural, Murat Cemcir           comedy
# 34883              Ata Demirer, Tuvana Türkay, Ülkü Duru           comedy
# 34884  YouTubers Shanna Malcolm, Shira Lazar, Sara Fl...  romantic comedy
# 34885  Halit Ergenç, Tuba Büyüküstün, Mehmet Günsür, ...         romantic
#
#                                                Wiki Page  \
# 0      https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1      https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2      https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3      https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4      https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# ...                                                  ...
# 34881    https://en.wikipedia.org/wiki/The_Water_Diviner
# 34882  https://en.wikipedia.org/wiki/%C3%87alg%C4%B1_...
# 34883         https://en.wikipedia.org/wiki/Olanlar_Oldu
# 34884  https://en.wikipedia.org/wiki/Non-Transferable...
# 34885  https://en.wikipedia.org/wiki/%C4%B0stanbul_K%...
#
#                                                     Plot
# 0      A bartender is working at a saloon, serving dr...
# 1      The moon, painted with a smiling face hangs ov...
# 2      The film, just over a minute long, is composed...
# 3      Lasting just 61 seconds and consisting of two ...
# 4      The earliest known adaptation of the classic f...
# ...                                                  ...
# 34881  The film begins in 1919, just after World War ...
# 34882  Two musicians, Salih and Gürkan, described the...
# 34883  Zafer, a sailor living with his mother Döndü i...
# 34884  The film centres around a young woman named Am...
# 34885  The writer Orhan Şahin returns to İstanbul aft...
#
# [34886 rows x 8 columns]

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
condition = df['Genre'] == "romantic comedy"
romantic_df = df[condition]
romantic_df
# Out:
#        Release Year                Title Origin/Ethnicity            Director  \
# 216            1918        Headin' South         American          Allan Dwan
# 226            1918           Mr. Fix-It         American          Allan Dwan
# 247            1918      The Venus Model         American  Clarence G. Badger
# 396            1921        Mama's Affair         American      Victor Fleming
# 452            1922        Up and at 'Em         American   William A. Seiter
# ...             ...                  ...              ...                 ...
# 34070          2000         Still Waters          Russian      Eldar Ryazanov
# 34137          2007  The Irony of Fate 2          Russian   Timur Bekmambetov
# 34190          2011        Lucky Trouble          Russian     Levan Gabriadze
# 34528          2011        You're My Pet     South_Korean             Unknown
# 34884          2017     Non-Transferable          Turkish     Brendan Bradley
#
#                                                     Cast            Genre  \
# 216               Douglas Fairbanks, Katherine MacDonald  romantic comedy
# 226                      Douglas Fairbanks, Wanda Hawley  romantic comedy
# 247                         Mabel Normand, Rod La Rocque  romantic comedy
# 396    Constance Talmadge, Effie Shannon, Kenneth Harlan  romantic comedy
# 452                             Doris May, Hallam Cooley  romantic comedy
# ...                                                  ...              ...
# 34070  Alexander Abdulov, Lyubov Polishchuk, Andrey M...  romantic comedy
# 34137                                                NaN  romantic comedy
# 34190  Konstantin Khabensky, Milla Jovovich, Ivan Urgant  romantic comedy
# 34528                                                NaN  romantic comedy
# 34884  YouTubers Shanna Malcolm, Shira Lazar, Sara Fl...  romantic comedy
#
#                                                Wiki Page  \
# 216        https://en.wikipedia.org/wiki/Headin%27_South
# 226    https://en.wikipedia.org/wiki/Mr._Fix-It_(1918...
# 247        https://en.wikipedia.org/wiki/The_Venus_Model
# 396        https://en.wikipedia.org/wiki/Mama%27s_Affair
# 452    https://en.wikipedia.org/wiki/Up_and_at_%27Em_...
# ...                                                  ...
# 34070  https://en.wikipedia.org/wiki/Still_Waters_(Ru...
# 34137  https://en.wikipedia.org/wiki/The_Irony_of_Fate_2
# 34190        https://en.wikipedia.org/wiki/Lucky_Trouble
# 34528  https://en.wikipedia.org/wiki/You%27re_My_Pet_...
# 34884  https://en.wikipedia.org/wiki/Non-Transferable...
#
#                                                     Plot
# 216    As described in a film magazine,[3] a forest r...
# 226    As described in a film magazine,[3] because of...
# 247    As described in a film magazine,[3] Kitty O'Br...
# 396    As summarized in a film publication,[4] a prol...
# 452    Wishing to drive her father's car, Barbara Jac...
# ...                                                  ...
# 34070  Anton M. Kashtanov (Alexander Abdulov) is a ta...
# 34137  The characters from the first film now have ch...
# 34190  Vyacheslav "Slava" Kolotilov (Konstantin Khabe...
# 34528  The film centers around a young and ambitious ...
# 34884  The film centres around a young woman named Am...
#
# [461 rows x 8 columns]

# %%
# This cell takes awhile to run

selected_col = df[["Genre", "Plot"]] # columns from the csv that we want to focus on

selected_genres = ["comedy", "drama", "adventure", "fantasy",
                  "horror", "mystery", "romance",
                 "action", "thriller", "western"] # select 10 genres

# Initialize an empty dictionary
movie = {}

# Iterate through the DataFrame rows
for index, row in selected_col.iterrows():
    genre = row['Genre']
    plot = row['Plot']

    # Check if genre exists in selected_genres
    if genre in selected_genres:
        if genre in movie:
            # Append the movie plot to the existing value
            # I did < 250 to ensure that every genre has less than 250 movies. This is because we had too much
            # text so I had to shorten it
            if len(movie[genre]) < 250:
                movie[genre].append(plot)
        else:
            # Create a new key-value pair
            movie[genre] = [plot]



# Right now, the result of movie looks like this:
# movie = {comedy: [movie1, movie2, movie3,...,movie250], action: [movie1, movie2, movie3,...,movie250]} and so on

# So the value of the key-value pairs is just a list of the movies

selected_col
# Out:
#                  Genre                                               Plot
# 0              unknown  A bartender is working at a saloon, serving dr...
# 1              unknown  The moon, painted with a smiling face hangs ov...
# 2              unknown  The film, just over a minute long, is composed...
# 3              unknown  Lasting just 61 seconds and consisting of two ...
# 4              unknown  The earliest known adaptation of the classic f...
# ...                ...                                                ...
# 34881          unknown  The film begins in 1919, just after World War ...
# 34882           comedy  Two musicians, Salih and Gürkan, described the...
# 34883           comedy  Zafer, a sailor living with his mother Döndü i...
# 34884  romantic comedy  The film centres around a young woman named Am...
# 34885         romantic  The writer Orhan Şahin returns to İstanbul aft...
#
# [34886 rows x 2 columns]

# %%
# print total amount of words in entire text corpus that we are analyzing
total_words = 0
for key in movie:
    for mov in movie[key]:
        total_words += len(mov.split(' '))
print(total_words)
# Out:
# 849167

# %%
# prints out the total amount of movies we are analyzing

total_movies = 0
for key in movie:
    total_movies += len(movie[key])
print(total_movies)
# Out:
# 2454

# %%
# So to get the text corpus for a particular genre, do something like:

# text = movie["comedy"]
# because this 'text' variable is a list (because the value from the key-value pair is a list)
# we want to make it a string
# so do something like new_text = "".join(text)
# get rid of stop words, normalize, lemmatize, etc, and make visualization from there

text = movie["comedy"]
#print(type(text))
new_text = "".join(text)
#print(type(new_text))

# get stop words
# tokenize/lemmatize depending on what your doing

# %%
def tokens(text):
  #stoplist = stopwords.words('english')
  #stoplist.extend([".", ",", "?", "could", "would", "“", "”", "’", ";", "!", "(", ")", "'s", "[", "]", '``', "''"])

  alltokens = nltk.word_tokenize(text)
  #allcontenttokens = [w for w in alltokens if w.lower() not in stoplist]

  return alltokens

# %%
# Professor Emily, ignore this function
#this function returns the most common unigrams and bigrams including stop words
def uniBigramsStopwords(text):
  stoplist = []
  #removes punctuation
  stoplist.extend([".", ",", "?", "“", "”", "’", ";", "!", "(", ")", "'s", "[", "]", '``', "''"])

  alltokens = nltk.word_tokenize(text)
  allcontenttokens = [w for w in alltokens if w.lower() not in stoplist]

  from nltk.stem import WordNetLemmatizer
  lemmatizer = WordNetLemmatizer()

  # create a new list of tokens, alllemmas by lemmatizing allcontenttokens
  all_lemmas = [lemmatizer.lemmatize(w) for w in allcontenttokens]

  unigrams = nltk.ngrams(all_lemmas, 1)
  unigramlist = list(unigrams)

  bigrams = nltk.ngrams(all_lemmas, 2)
  bigramlist = list(bigrams)

  # print out most frequent bigrams and unigrams
  bigramfreq = nltk.FreqDist(bigramlist)
  unigramfreq = nltk.FreqDist(unigramlist)
  maxBigrams = bigramfreq.most_common(50)
  maxUnigrams = unigramfreq.most_common(20)
  return [maxBigrams, maxUnigrams]

# %%
#this function returns the most common bigrams without stopwords
def bigrams(text):
  stoplist = stopwords.words('english')
  stoplist.extend([".", ",", "?", "could", "would", "“", "”", "’", ";", "!", "(", ")", "'s", "[", "]", '``', "''"])

  tokenlist = nltk.word_tokenize(text)
  bigrams = nltk.ngrams(tokenlist, 2)
  bigramlist = list(bigrams)

  # print out most frequent bigrams
  bigramfreq = nltk.FreqDist(bigramlist)
  #print(bigramfreq.most_common(10))

  # print out most frequent bigrams where neither word is a stop word
  for b in bigramfreq.most_common(1000):
      if b[0][0].lower() not in stoplist and b[0][1].lower() not in stoplist:
          print(b)

 #  textTokens = tokens(text)

  #bigrams = nltk.ngrams(textTokens, 2)
  #bigramlist = list(bigrams)
  #bigramfreq = nltk.FreqDist(bigramlist)
  #maxBigrams = bigramfreq.most_common(5)

# %%
#Bigram finder, prints out bigrams for each genre
for genre in selected_genres:
  text = movie[genre]
  new_text = "".join(text)
  print(genre, bigrams(new_text))
# Out:
# (('young', 'man'), 40)
# (('young', 'woman'), 24)
# (('New', 'York'), 18)
# (('Mrs.', 'Erlynne'), 17)
# (('film', 'magazine'), 13)
# (('returns', 'home'), 11)
# (('next', 'day'), 11)
# (('film', 'ends'), 10)
# (('Buster', 'Keaton'), 10)
# (('delivery', 'boy'), 10)
# (('Lady', 'Windermere'), 9)
# (('Mrs.', 'Rittenhouse'), 9)
# (('United', 'States'), 8)
# (('Little', 'Tramp'), 7)
# (('Lord', 'Helpus'), 7)
# (('two', 'men'), 7)
# (('Harold', 'Lloyd'), 7)
# (('get', 'married'), 7)
# (('next', 'morning'), 7)
# (('Sir', 'Basil'), 7)
# (('ca', "n't"), 6)
# (('World', 'War'), 6)
# (('small', 'town'), 6)
# (('little', 'girl'), 6)
# (('York', 'City'), 6)
# comedy None
# (('film', 'magazine'), 57)
# (('New', 'York'), 34)
# (('One', 'day'), 21)
# (('Sir', 'Daniel'), 15)
# (('young', 'man'), 14)
# (('next', 'day'), 13)
# (('York', 'City'), 13)
# (('Aunt', 'Polly'), 13)
# (('years', 'later'), 12)
# (('young', 'woman'), 11)
# (('returns', 'home'), 10)
# (('World', 'War'), 10)
# (('film', 'publication'), 10)
# (('San', 'Francisco'), 9)
# (('One', 'night'), 8)
# (('Officer', 'Rooney'), 8)
# (('next', 'morning'), 7)
# (('Mary', 'Pickford'), 7)
# (('Lillian', 'Gish'), 7)
# (('United', 'States'), 7)
# (('film', 'opens'), 7)
# (('$', '5,000'), 7)
# (('runs', 'away'), 6)
# (('man', 'named'), 6)
# (('Moat', 'House'), 6)
# (('old', 'man'), 6)
# (('New', 'England'), 6)
# (('older', 'brother'), 6)
# (('Lon', 'Chaney'), 6)
# (('John', 'Gilbert'), 6)
# (('Dr.', 'Besant'), 6)
# drama None
# (('Johnny', 'Pacific'), 23)
# (('United', 'States'), 19)
# (('de', 'Maynes'), 17)
# (('next', 'day'), 16)
# (('Kim', 'Kim'), 16)
# (('la', 'Tour'), 15)
# (('Carl', 'Denham'), 15)
# (('Jungle', 'Jim'), 15)
# (('de', 'la'), 14)
# (('King', 'Richard'), 14)
# (('New', 'York'), 12)
# (('two', 'men'), 12)
# (('Rin', 'Tin'), 11)
# (('Tin', 'Tin'), 11)
# (('Lady', 'Benedetta'), 11)
# (('first', 'mate'), 10)
# (('Johnny', 'Weissmuller'), 10)
# (('One', 'day'), 9)
# (('King', 'Louis'), 9)
# (('next', 'morning'), 9)
# (('mortally', 'wounded'), 9)
# (('El', 'Libre'), 9)
# (('Black', 'Knight'), 9)
# (('Long', 'John'), 8)
# (('John', 'Silver'), 8)
# (('true', 'identity'), 8)
# (('Lady', 'Anne'), 8)
# (('Ti', 'Shen'), 8)
# (('Baron', 'Gruda'), 8)
# (('Prince', 'John'), 8)
# adventure None
# (('Little', 'Bear'), 37)
# (('next', 'day'), 32)
# (('White', 'Snake'), 28)
# (('Green', 'Snake'), 24)
# (('next', 'morning'), 19)
# (('ca', "n't"), 17)
# (('Hsui', 'Xien'), 17)
# (('years', 'later'), 16)
# (('magic', 'lamp'), 14)
# (('years', 'ago'), 13)
# (('Nanny', 'McPhee'), 13)
# (('World', 'War'), 12)
# (('United', 'States'), 12)
# (('New', 'York'), 12)
# (('Mr.', 'Scratch'), 12)
# (('real', 'world'), 12)
# (('One', 'day'), 12)
# (('Death', 'Eaters'), 12)
# (('human', 'form'), 11)
# (('returns', 'home'), 11)
# (('Cool', 'World'), 11)
# (('One', 'night'), 11)
# fantasy None
# (('Lady', 'Jane'), 62)
# (('next', 'day'), 47)
# (('next', 'morning'), 46)
# (('Sir', 'Frederick'), 40)
# (('Van', 'Helsing'), 28)
# (('young', 'woman'), 24)
# (('New', 'York'), 21)
# (('following', 'morning'), 17)
# (('Professor', 'Saunders'), 16)
# (('Mrs.', 'Kinsolving'), 16)
# (('following', 'day'), 15)
# (('Los', 'Angeles'), 15)
# (('tana', 'leaves'), 14)
# (('One', 'night'), 14)
# (('Mrs.', 'Tredoni'), 14)
# (('Tall', 'Man'), 14)
# (('Bela', 'Lugosi'), 13)
# (('years', 'later'), 13)
# (('film', 'ends'), 13)
# (('full', 'moon'), 13)
# (('Vincent', 'Price'), 13)
# (('young', 'man'), 12)
# (('Lon', 'Chaney'), 12)
# (('old', 'woman'), 12)
# (('still', 'alive'), 12)
# horror None
# (('Lone', 'Wolf'), 40)
# (('New', 'York'), 32)
# (('found', 'dead'), 21)
# (('Los', 'Angeles'), 21)
# (('Charlie', 'Chan'), 18)
# (('San', 'Francisco'), 17)
# (('next', 'morning'), 16)
# (('next', 'day'), 15)
# (('two', 'men'), 14)
# (('private', 'detective'), 14)
# (('Police', 'Inspector'), 14)
# (('jewel', 'thief'), 12)
# (('Scotland', 'Yard'), 12)
# (('hotel', 'room'), 12)
# (('Miss', 'Withers'), 12)
# (('real', 'murderer'), 11)
# (('dead', 'body'), 11)
# (('Miss', 'Froy'), 11)
# (('dead', 'man'), 10)
# (('police', 'arrive'), 10)
# (('La', 'Tour'), 10)
# (('Sherlock', 'Holmes'), 10)
# (('York', 'City'), 10)
# (('World', 'War'), 10)
# (('air', 'raid'), 10)
# (('Tom', 'Conway'), 9)
# (('private', 'investigator'), 9)
# (('even', 'though'), 8)
# (('prime', 'suspect'), 8)
# (('committed', 'suicide'), 8)
# (('phone', 'call'), 8)
# (('man', 'named'), 8)
# mystery None
# (('New', 'York'), 76)
# (('next', 'day'), 46)
# (('York', 'City'), 33)
# (('next', 'morning'), 25)
# (('young', 'woman'), 19)
# (('get', 'married'), 19)
# (('One', 'day'), 17)
# (('Juan', 'Antonio'), 17)
# (('one', 'another'), 15)
# (('World', 'War'), 15)
# (('first', 'time'), 15)
# (('ca', "n't"), 13)
# (('One', 'night'), 13)
# (('years', 'later'), 13)
# (('best', 'friend'), 13)
# (('high', 'school'), 13)
# (('Anne', 'Marie'), 13)
# (('even', 'though'), 12)
# (('Sir', 'Julian'), 12)
# (('War', 'II'), 12)
# (('make', 'love'), 12)
# (('Uncle', 'Jed'), 12)
# (('time', 'together'), 11)
# (('young', 'man'), 10)
# (('San', 'Francisco'), 10)
# (('say', 'goodbye'), 10)
# (("n't", 'know'), 10)
# (('New', 'Year'), 10)
# (('goes', 'back'), 10)
# (('lake', 'house'), 10)
# (('one', 'night'), 9)
# (('come', 'back'), 9)
# romance None
# (('United', 'States'), 39)
# (('New', 'York'), 36)
# (('Red', 'Skull'), 36)
# (('Los', 'Angeles'), 34)
# (('martial', 'arts'), 27)
# (('Hong', 'Kong'), 25)
# (('next', 'day'), 25)
# (('gang', 'members'), 23)
# (('York', 'City'), 18)
# (('rocket', 'pack'), 17)
# (('Lo', 'Pan'), 16)
# (('Air', 'Force'), 15)
# (('Vietnam', 'War'), 15)
# (('police', 'officer'), 15)
# (('wo', "n't"), 14)
# (('high', 'school'), 13)
# (('upper', 'hand'), 13)
# (('film', 'ends'), 13)
# (('woman', 'named'), 12)
# (('old', 'friend'), 12)
# (('two', 'men'), 12)
# (('police', 'officers'), 12)
# (('Rubber', 'Duck'), 12)
# (('Black', 'Star'), 12)
# (('Red', 'River'), 11)
# (('Chuck', 'Norris'), 11)
# (('Captain', 'Red'), 11)
# (('San', 'Francisco'), 10)
# (('years', 'ago'), 10)
# action None
# (('New', 'York'), 62)
# (('next', 'day'), 39)
# (('York', 'City'), 28)
# (('Los', 'Angeles'), 28)
# (('Mrs.', 'Mott'), 25)
# (('next', 'morning'), 22)
# (('two', 'men'), 20)
# (('young', 'woman'), 19)
# (('Mr.', 'Gallico'), 19)
# (('film', 'ends'), 18)
# (('United', 'States'), 17)
# (('phone', 'call'), 16)
# (('gas', 'station'), 16)
# (('Mrs.', 'Blake'), 15)
# (('serial', 'killer'), 15)
# (('returns', 'home'), 14)
# (('police', 'officer'), 13)
# (('old', 'friend'), 12)
# (('One', 'day'), 12)
# (('Mrs.', 'Warren'), 12)
# (('Mr.', 'Ormond'), 12)
# (('days', 'later'), 12)
# (('Buffalo', 'Bill'), 12)
# (('crime', 'scene'), 11)
# (('Gin', 'Sling'), 11)
# (('front', 'door'), 11)
# (('man', 'named'), 11)
# thriller None
# (('Gene', 'Autry'), 40)
# (('wagon', 'train'), 25)
# (('Smiley', 'Burnette'), 20)
# (('Frog', 'Millhouse'), 19)
# (('next', 'day'), 17)
# (('Betty', 'Lou'), 16)
# (('John', 'Wayne'), 13)
# (('Civil', 'War'), 12)
# (('San', 'Francisco'), 12)
# (('bad', 'guys'), 12)
# (('dance', 'hall'), 11)
# (('New', 'York'), 11)
# (('old', 'friend'), 11)
# (('sidekick', 'Frog'), 11)
# (('old', 'man'), 11)
# (('World', 'Wide'), 11)
# (('United', 'States'), 10)
# (('Roy', 'Rogers'), 10)
# (('film', 'magazine'), 9)
# (('two', 'men'), 9)
# (('Santa', 'Fe'), 9)
# (('Randolph', 'Scott'), 9)
# (('Utah', 'Joe'), 9)
# (('Dodge', 'City'), 9)
# (('leave', 'town'), 8)
# (('Sometime', 'later'), 8)
# (('years', 'later'), 8)
# (('cattle', 'rustlers'), 8)
# (('singing', 'cowboy'), 8)
# (('Pecos', 'Bill'), 8)
# (('cowboy', 'Gene'), 8)
# (('Virginia', 'City'), 8)
# (('New', 'Mexico'), 8)
# (('Circle', 'R'), 8)
# (('Western', 'Union'), 8)
# (('rest', 'stop'), 8)
# (('Big', 'Bill'), 8)
# (('Red', 'Cardell'), 8)
# (('Miss', 'Martin'), 8)
# (('poker', 'game'), 7)
# (('Gary', 'Cooper'), 7)
# (('new', 'sheriff'), 7)
# western None

# %%
def getText(genre):
  text = movie[genre]
  new_text = "".join(text)
  return new_text

# %%
print(getText("comedy"))

# %%
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.collocations import *

def collocations(genre):
  text = getText(genre)
  tokenList = nltk.word_tokenize(text)

  bigram_measures = nltk.collocations.BigramAssocMeasures()
  finder = BigramCollocationFinder.from_words(tokenList)
  finder.apply_freq_filter(25)
  for c in finder.nbest(bigram_measures.pmi, 10):
    print(" ".join(c))



  #bigram_finder.apply_freq_filter(3)  # Adjust the frequency filter as needed



  #collocations = bigram_finder.nbest(BigramAssocMeasures.likelihood_ratio, 10)

  # Print Collocations
  #print("Genre:" + genre)
  #print("Collocations:", collocations[0:3])

# %%
# prints out collocations for each genre
# there's a lot of not interesting collocations, most of the interesting ones overlap with common bigrams
for genre in selected_genres:
  print(genre + "__________")
  collocations(genre)
# Out:
# comedy__________
# does not
# turns out
# young man
# has been
# love with
# her husband
# in order
# they are
# in love
# his wife
# drama__________
# New York
# film magazine
# 3 ]
# [ 3
# 2 ]
# [ 2
# 4 ]
# [ 4
# 1 ]
# does not
# adventure__________
# ’ s
# has been
# learns that
# in order
# ( Robert
# his wife
# they are
# in love
# his own
# love with
# fantasy__________
# Little Bear
# White Snake
# each other
# next day
# does n't
# does not
# had been
# have been
# as well
# has been
# horror__________
# Van Helsing
# ’ s
# Sir Frederick
# [ 1
# 1 ]
# Lady Jane
# next morning
# next day
# That night
# does not
# mystery__________
# Lone Wolf
# New York
# ’ s
# does not
# turns out
# have been
# had been
# has been
# love with
# they are
# romance__________
# ’ s
# York City
# New York
# each other
# next morning
# next day
# does n't
# shows up
# does not
# The next
# action__________
# Hong Kong
# Los Angeles
# martial arts
# United States
# New York
# ’ s
# Red Skull
# next day
# each other
# does not
# thriller__________
# Los Angeles
# ’ s
# New York
# York City
# Mrs. Mott
# next day
# does not
# has been
# can not
# The next
# western__________
# ’ s
# 2 ]
# [ 2
# wagon train
# does not
# Gene Autry
# has been
# learns that
# love with
# in order
